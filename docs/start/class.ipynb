// %% [markdown]
// # 类
//
// ```{admonition} 需求
// 学习自定义类型的方法。
// ```
//
// ```{hint}
// {guilabel}`视频`
//
// ...
// ```

// %%
constexpr int max = 500;

int use(int n) {
    //
}

// %%
int ablog(int b) {
    return b + 1;
}

// %%
int max = 500;

int use(int n) {
//     int c1 = max + 7; // 正确，c1 是 507
    return 0;
}
// Out:
// input_line_9:3:16: error: function definition is not allowed here
// int use(int n) {
//                ^
// Interpreter Error:

// %%
max(2)
// Out:
// input_line_8:2:2: error: use of undeclared identifier 'max'; did you mean 'std::max'?
//  max(2)
//  ^~~
//  std::max
// /../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/algorithmfwd.h:370:5: note: 'std::max' declared here
//     max(const _Tp&, const _Tp&);
//     ^
// input_line_8:2:2: error: no matching function for call to 'max'
//  max(2)
//  ^~~
// /../lib/gcc/x86_64-linux-gnu/9/../../../../include/c++/9/bits/algorithmfwd.h:370:5: note: candidate function template not viable: requires 2 arguments, but 1 was provided
//     max(const _Tp&, const _Tp&);
//     ^
// Interpreter Error:
